# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/My Drive/Custom/Custom/YoloV3"
import sys
sys.path.append(path)
# %load_ext autoreload
# %autoreload 2

# %%
# %cd /content/drive/My Drive/Custom/Custom/YoloV3
# Out:
# /content/drive/My Drive/Custom/Custom/YoloV3

# %%
ls
# Out:
#  cfg/         process.py     test_batch0.png   'ubdivisions=1'
#  data/        __pycache__/   test.py            utils/
#  detect.py    results.png    ting               video_processed/
#  models.py    results.txt    train_batch0.png   vim.exe.stackdump
#  out_outhi/   runs/          train.py           weights/

# %%
import time
import glob
import torch
import os
import warnings

warnings.filterwarnings('ignore')

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.10.0+cu111 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
# !ls
# Out:
#  cfg	     process.py    test_batch0.png   'ubdivisions=1'
#  data	     __pycache__   test.py	      utils
#  detect.py   results.png   ting		      video_processed
#  models.py   results.txt   train_batch0.png   vim.exe.stackdump
#  out_outhi   runs	   train.py	      weights

# %%
# !python '/content/drive/My Drive/Custom/Custom/YoloV3/train.py' --data '/content/drive/My Drive/Custom/Custom/YoloV3/data/customdata/custom.data' --batch 5 --cache --cfg '/content/drive/My Drive/Custom/Custom/YoloV3/cfg/yolov3-custom.cfg' --epochs 50 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=5, bucket='', cache_images=True, cfg='/content/drive/My Drive/Custom/Custom/YoloV3/cfg/yolov3-custom.cfg', data='/content/drive/My Drive/Custom/Custom/YoloV3/data/customdata/custom.data', device='', epochs=50, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (90 found, 0 missing, 0 empty, 0 duplicate, for 90 images): 100% 90/90 [00:21<00:00,  4.14it/s]
# Caching images (0.1GB): 100% 90/90 [00:19<00:00,  4.57it/s]
# ...

# %%
# !python '/content/drive/My Drive/Custom/Custom/YoloV3/detect.py' --conf-thres 0.1 --output out_outhi
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_outhi', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/100 data/customdata/images/img001.jpg: 320x512 1 vests, 1 masks, 1 bootss, Done. (0.063s)
# image 2/100 data/customdata/images/img002.jpg: 384x512 1 hardhats, Done. (0.092s)
# ...

# %%
Image(filename='/content/drive/My Drive/Custom/Custom/YoloV3/out_outhi/img010.jpg', width=600)

# %%
Image(filename='/content/drive/My Drive/Custom/Custom/YoloV3/out_outhi/img051.jpg', width=600)

# %%
Image(filename='/content/drive/My Drive/Custom/Custom/YoloV3/out_outhi/img019.jpg', width=600)
