# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/My Drive/Custom/Custom/YoloV3"
import sys
sys.path.append(path)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %cd /content/drive/My Drive/Custom/Custom/YoloV3
# Out:
# /content/drive/My Drive/Custom/Custom/YoloV3

# %%
ls
# Out:
#  cfg/         process.py        test.py            video_processed/
#  data/        __pycache__/      ting               vim.exe.stackdump
#  detect.py    results.png       train_batch0.png   weights/
#  frames/      results.txt       train.py           youtube_video.mp4
#  models.py    runs/            'ubdivisions=1'
#  out_outhi/   test_batch0.png   utils/

# %%
import time
import glob
import torch
import os
import warnings

warnings.filterwarnings('ignore')

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.10.0+cu111 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
ls
# Out:
#  cfg/         process.py        test.py            video_processed/
#  data/        __pycache__/      ting               vim.exe.stackdump
#  detect.py    results.png       train_batch0.png   weights/
#  frames/      results.txt       train.py           youtube_video.mp4
#  models.py    runs/            'ubdivisions=1'
#  out_outhi/   test_batch0.png   utils/

# %%
# !python '/content/drive/My Drive/Custom/Custom/YoloV3/detect.py' --conf-thres 0.2 --output video_processed
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.2, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='video_processed', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/32 data/customdata/images/out-001.jpg: 320x512 Done. (0.084s)
# image 2/32 data/customdata/images/out-002.jpg: 320x512 Done. (0.080s)
# ...

# %%
Image(filename='/content/drive/My Drive/Custom/Custom/YoloV3/video_processed/img100.jpg', width=600)

# %%
Image(filename='/content/drive/My Drive/Custom/Custom/YoloV3/video_processed/img050.jpg', width=600)
